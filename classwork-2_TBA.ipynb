# %% [markdown]
# # Importing libraries

# %%
# importing pandas and seaborn libraries as pd and sns
import pandas as pd
import seaborn as sns
import regex as re
import nltk

# %% [markdown]
# # Opens the CSV file

# %%
#creating a dataframe
file="C:\\Users\\Ramachandraiah\\Downloads\\un-general-debates-blueprint.csv"
df = pd.read_csv(file)
df
# Out:
#       session  year country  country_name                            speaker  \
# 0          25  1970     ALB       Albania                            Mr. NAS
# 1          25  1970     ARG     Argentina                 Mr. DE PABLO PARDO
# 2          25  1970     AUS     Australia                        Mr. McMAHON
# 3          25  1970     AUT       Austria                 Mr. KIRCHSCHLAEGER
# 4          25  1970     BEL       Belgium                         Mr. HARMEL
# ...       ...   ...     ...           ...                                ...
# 7502       70  2015     YEM         Yemen  Mr. Abdrabuh Mansour Hadi Mansour
# 7503       70  2015     YUG    Yugoslavia               Mr. Tomislav Nikolić
# 7504       70  2015     ZAF  South Africa                         Jacob Zuma
# 7505       70  2015     ZMB        Zambia             Mr. Edgar Chagwa Lungu
# 7506       70  2015     ZWE      Zimbabwe                      Robert Mugabe
#
#        position                                               text
# 0           NaN  33: May I first convey to our President the co...
# 1           NaN  177.\t : It is a fortunate coincidence that pr...
# 2           NaN  100.\t  It is a pleasure for me to extend to y...
# 3           NaN  155.\t  May I begin by expressing to Ambassado...
# 4           NaN  176. No doubt each of us, before coming up to ...
# ...         ...                                                ...
# 7502  President  On behalf of the people and the Government of ...
# 7503  President  \nSeventy years have passed since the establis...
# 7504  President  I should like to congratulate the President an...
# 7505  President  I would like to begin by thanking the Secretar...
# 7506  President  Allow me at the outset to extend to Mr. Mogens...
#
# [7507 rows x 7 columns]

# %%
#displaying first 20 of a dataframe
df.head(20)
# Out:
#     session  year country                     country_name  \
# 0        25  1970     ALB                          Albania
# 1        25  1970     ARG                        Argentina
# 2        25  1970     AUS                        Australia
# 3        25  1970     AUT                          Austria
# 4        25  1970     BEL                          Belgium
# 5        25  1970     BLR                          Belarus
# 6        25  1970     BOL  Bolivia, Plurinational State of
# 7        25  1970     BRA                           Brazil
# 8        25  1970     CAN                           Canada
# 9        25  1970     CMR                         Cameroon
# 10       25  1970     COG                            Congo
# 11       25  1970     COL                         Colombia
# 12       25  1970     CRI                       Costa Rica
# 13       25  1970     CUB                             Cuba
# 14       25  1970     DOM               Dominican Republic
# 15       25  1970     DZA                          Algeria
# 16       25  1970     ECU                          Ecuador
# 17       25  1970     FRA                           France
# 18       25  1970     GBR                   United Kingdom
# 19       25  1970     GHA                            Ghana
#
#                   speaker    position  \
# 0                 Mr. NAS         NaN
# 1      Mr. DE PABLO PARDO         NaN
# 2             Mr. McMAHON         NaN
# 3      Mr. KIRCHSCHLAEGER         NaN
# 4              Mr. HARMEL         NaN
# 5          Mr. GURINOVICH         NaN
# 6      Mr. CAMACHO OMISTE         NaN
# 7      Mr. GIBSON BARBOZA         NaN
# 8               Mr. SHARP         NaN
# 9              Mr. AHIDJO  President
# 10            Mr. ICKONGA         NaN
# 11  Mr. VASQUEZ CARRIZOSA         NaN
# 12              Mr. FACIO         NaN
# 13            Mr. ALARCON         NaN
# 14        Mr FERNANDEZ G.
# 15              Mr. YAZID         NaN
# 16            Mr. Benites         NaN
# 17           Mr. SCHUMANN         NaN
# 18   Sir Alec DOUGLASHOME         NaN
# 19              Mr. OWUSU         NaN
#
#                                                  text
# 0   33: May I first convey to our President the co...
# 1   177.\t : It is a fortunate coincidence that pr...
# 2   100.\t  It is a pleasure for me to extend to y...
# 3   155.\t  May I begin by expressing to Ambassado...
# 4   176. No doubt each of us, before coming up to ...
# 5   \n71.\t. We are today mourning the untimely de...
# 6   135.\t  I wish to congratulate the President o...
# 7   1.\tMr. President, I should like, first of all...
# 8   \nThe General Assembly is fortunate indeed to ...
# 9   : A year ago I came here as the Acting Preside...
# 10  122.\t  I cannot begin my intervention without...
# 11  Mr. President, this visit to the United Nation...
# 12  62.\t  Mr. President, your election to the Pre...
# 13  1.\t  Mr. President, I should first like to co...
# 14  \n\n\n Mr. President, it was a source of great...
# 15  1.  The delegation of Algeria is very pleased ...
# 16  71.  It had been my hope that a loftier person...
# 17  84.\t  Within one month, when we celebrate the...
# 18  110.\t Mr. President, I should like first to s...
# 19  121.\t I should like to begin by congratulatin...

# %% [markdown]
# # Sample fraction

# %%
#displaying the dimensions of dataframe
#df=df.sample(frac=0.2)
df.shape
# Out:
# (7507, 7)

# %% [markdown]
# # Overview of a dataframe

# %%
df.columns #displaying column names
df.dtypes #displaying datatype of each column
df.info() #creating the dataframe info
df.describe() #displaying the description of dataframe
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7507 entries, 0 to 7506
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   session       7507 non-null   int64
#  1   year          7507 non-null   int64
#  2   country       7507 non-null   object
#  3   country_name  7507 non-null   object
#  4   speaker       7480 non-null   object
#  5   position      4502 non-null   object
#  6   text          7507 non-null   object
# dtypes: int64(2), object(5)
# memory usage: 410.7+ KB
#            session         year
# count  7507.000000  7507.000000
# mean     49.610763  1994.610763
# std      12.892155    12.892155
# min      25.000000  1970.000000
# 25%      39.000000  1984.000000
# 50%      51.000000  1996.000000
# 75%      61.000000  2006.000000
# max      70.000000  2015.000000

# %% [markdown]
# # Length of speeches

# %%
df['length'] = df['text'].str.len() #displaying a new column  as length
df.describe()# displayig describe of dataframe
# Out:
#            session         year        length
# count  7507.000000  7507.000000   7507.000000
# mean     49.610763  1994.610763  17967.281604
# std      12.892155    12.892155   7860.038463
# min      25.000000  1970.000000   2362.000000
# 25%      39.000000  1984.000000  12077.000000
# 50%      51.000000  1996.000000  16424.000000
# 75%      61.000000  2006.000000  22479.500000
# max      70.000000  2015.000000  72041.000000

# %% [markdown]
# # Stats about text fields

# %%
df.describe(include='O') #desplaying categorical columns in a dataframe
# Out:
#        country country_name        speaker                      position  \
# count     7507         7507           7480                          4502
# unique     199          199           5428                           113
# top        ALB      Albania  Seyoum Mesfin  Minister for Foreign Affairs
# freq        46           46             12                          1813
#
#                                                      text
# count                                                7507
# unique                                               7507
# top     33: May I first convey to our President the co...
# freq                                                    1

# %% [markdown]
# # Check for missing data

# %%
df.isna().sum()#finding missing values of each column of dataframe
# Out:
# session            0
# year               0
# country            0
# country_name       0
# speaker           27
# position        3005
# text               0
# length             0
# dtype: int64

# %% [markdown]
# # fill the missing data

# %%
df['speaker'].fillna('unknown', inplace=True) #filling missing values of a speaker as unknown
df['position'].fillna('unknown', inplace=True)#filling missing values of a position as unknown
df.isna().sum()#finding missing values of each column of dataframe
# Out:
# session         0
# year            0
# country         0
# country_name    0
# speaker         0
# position        0
# text            0
# length          0
# dtype: int64

# %% [markdown]
# # Uppercase

# %%
#converting values of speaker, position and text into uppercase
df['speaker']= df['speaker'].str.upper()
df['position']=df['position'].str.upper()
df['text']=df['text'].str.upper()

# %% [markdown]
# # Problem with text

# %%
df[df['speaker'].str.contains('BUSH')]
# Out:
#       session  year country   country_name             speaker   position  \
# 2720       44  1989     USA  United States                BUSH  PRESIDENT
# 2876       45  1990     USA  United States         GEORGE BUSH    UNKNOWN
# 3038       46  1991     USA  United States         GEORGE BUSH  PRESIDENT
# 3207       47  1992     USA  United States     MR. GEORGE BUSH  PRESIDENT
# 4814       56  2001     USA  United States      GEORGE W. BUSH  PRESIDENT
# 5002       57  2002     USA  United States  MR. GEORGE W. BUSH  PRESIDENT
# 5191       58  2003     USA  United States      GEORGE W. BUSH  PRESIDENT
# 5382       59  2004     USA  United States   MR. GEORGE W BUSH  PRESIDENT
# 5760       61  2006     USA  United States  MR. GEORGE W. BUSH  PRESIDENT
# 5951       62  2007     USA  United States      GEORGE W. BUSH  PRESIDENT
# 6143       63  2008     USA  United States      GEORGE W. BUSH  PRESIDENT
#
#                                                    text  length
# 2720  ﻿I AM HONOURED TO ADDRESS THE GENERAL ASSEMBLY...   19779
# 2876  ﻿\nIT IS REALLY A GREAT PRIVILEGE TO GREET YOU...   15843
# 3038  ﻿I AM HONOURED TO SPEAK WITH YOU AS YOU OPEN T...   15555
# 3207  FORTY-SEVEN YEARS AGO I WAS A YOUNG MAN OF 21,...   21105
# 4814  ﻿WE MEET IN A HALL DEVOTED TO\nPEACE; IN A CIT...   14724
# 5002  ﻿WE MEET ONE YEAR AND ONE DAY\nAFTER A TERRORI...   16684
# 5191  ﻿TWENTY-FOUR MONTHS AGO, AND\nYESTERDAY IN THE...   16962
# 5382  THANK YOU FOR THE HONOUR OF\nADDRESSING THE GE...   18628
# 5760  I AM GRATEFUL FOR THE PRIVILEGE OF \nSPEAKING ...   16675
# 5951  THANK YOU FOR THE OPPORTUNITY \nTO ADDRESS THE...   15483
# 6143  I AM PLEASED TO BE HERE TO \nADDRESS THE GENER...   18384

# %% [markdown]
# # charts

# %%
df['length'].plot() # plotting graph for length column
# Out:
# <Axes: >

# %%
df['length'].plot(kind='box', vert=False) #creating a horizontal boxplot for length column
# Out:
# <Axes: >

# %% [markdown]
# # Histogram

# %%
df['length'].plot(kind='hist', bins=30) #finding histogram for length column with 30 bins
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# # Barplot

# %%
where = df['country'].isin(['USA', 'FRA', 'GBR', 'CHN', 'RUS']) #filtering rows based on country
g = sns.catplot(data=df[where], x="country", y="length", kind='box') #generating box plot
g.fig.set_size_inches(10, 8) #setting figure size
# Out:
# C:\Users\Ramachandraiah\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# # Function to tokenize

# %%
def tokenize(text):
    return re.findall(r'[\w-]*[a-z|A-Z][\w-]*', text)

# %%
testtext = "Let's defeat SARS-CoV-2 together in 2020! www.cdc.gov" #sample text
testtokens = tokenize(testtext) #by using tokenize function tokenize sample text
print(testtokens) #printing the list of testtokens
# Out:
# ['Let', 's', 'defeat', 'SARS-CoV-2', 'together', 'in', 'www', 'cdc', 'gov']

# %%
nltk.download('stopwords') #downloading the stopwords from nltk
stopwords = set(nltk.corpus.stopwords.words('english')) # Get the list of English stopwords and arrange them in a list.
print(stopwords) #printing the output of stopwords
# Out:
# {'any', 'haven', 'some', 'having', 'all', 'itself', 'or', 'that', 'had', 'needn', 'its', 'have', 'but', 'until', 'doing', 'yourself', "don't", 'because', 'so', 'between', 'won', 'ourselves', "you're", 'very', 'can', 'through', 'isn', 'has', 'what', 's', 'up', 'for', 'are', 'more', 'both', 'off', 'same', 'once', 'do', 'which', 're', "weren't", 'her', 'than', 'his', "she's", 'down', 'over', 'while', 'doesn', "wouldn't", 'being', "mightn't", 'my', "that'll", 'if', 'him', 'an', 'above', 'll', "doesn't", 'didn', 'm', 'during', 'few', 'don', 'shan', 'by', 'those', 'at', 'them', "shan't", 'he', 'out', 'yourselves', 'no', 'our', 'will', 'ain', 'to', 'nor', 'as', 'weren', 'theirs', 'couldn', 'now', 'into', 'you', 'not', 'shouldn', 'your', "you've", 'the', "needn't", 'against', 'after', 'before', 'too', 'be', 'mustn', 'own', 'me', 'how', 'should', 'a', 'with', "won't", "hasn't", "you'll", 'd', 've', "wasn't", "isn't", "couldn't", 'we', "should've", 'it', 'aren', 'in', 'am', "you'd", 'hers', 'was', 'just', 'and', 'does', 'she', 'hasn', 'where', "aren't", "hadn't", 'here', 'again', 't', 'wasn', 'there', 'they', 'been', "it's", "didn't", "shouldn't", 'from', 'yours', 'mightn', 'why', 'himself', 'is', 'i', 'such', 'other', 'wouldn', 'hadn', 'themselves', 'about', 'when', "mustn't", 'each', 'ma', 'under', 'further', 'most', 'herself', 'below', 'their', 'myself', 'did', 'who', 'of', "haven't", 'ours', 'this', 'on', 'whom', 'then', 'only', 'o', 'these', 'y', 'were'}
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Ramachandraiah\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# # Function to remove Stop words

# %%
def remove_stop(tokens):
    return [t for t in tokens if t.lower() not in     # Removing stopwords from the list of tokens

            stopwords]
cleantokens= remove_stop(testtokens) # Testing the remove_stop function with testtokens
print(cleantokens)
# Out:
# ['Let', 'defeat', 'SARS-CoV-2', 'together', 'www', 'cdc', 'gov']

# %% [markdown]
# # Make a pipeline

# %%
pipeline = [str.lower, tokenize, remove_stop]
def prepare(text, pipeline): #Set the input text as the token's initial value.
    tokens = text  # Apply each function in the pipeline to the tokens
    for fun in pipeline:
        tokens = fun(tokens)
    return tokens #returns the tokens

# %% [markdown]
# # Run the Pipeline

# %%
df['tokens'] = df['text'].apply(prepare, pipeline=pipeline)

# %% [markdown]
# # count the tokens

# %%
df['num_tokens'] = df['tokens'].map(len)

# %%
df.tail() #displays last five of a dataframe
# Out:
#       session  year country  country_name                            speaker  \
# 7502       70  2015     YEM         Yemen  MR. ABDRABUH MANSOUR HADI MANSOUR
# 7503       70  2015     YUG    Yugoslavia               MR. TOMISLAV NIKOLIĆ
# 7504       70  2015     ZAF  South Africa                         JACOB ZUMA
# 7505       70  2015     ZMB        Zambia             MR. EDGAR CHAGWA LUNGU
# 7506       70  2015     ZWE      Zimbabwe                      ROBERT MUGABE
#
#        position                                               text  length  \
# 7502  PRESIDENT  ON BEHALF OF THE PEOPLE AND THE GOVERNMENT OF ...   10568
# 7503  PRESIDENT  \nSEVENTY YEARS HAVE PASSED SINCE THE ESTABLIS...   25430
# 7504  PRESIDENT  I SHOULD LIKE TO CONGRATULATE THE PRESIDENT AN...   13662
# 7505  PRESIDENT  I WOULD LIKE TO BEGIN BY THANKING THE SECRETAR...   14247
# 7506  PRESIDENT  ALLOW ME AT THE OUTSET TO EXTEND TO MR. MOGENS...   11013
#
#                                                  tokens  num_tokens
# 7502  [behalf, people, government, yemen, would, lik...         894
# 7503  [seventy, years, passed, since, establishment,...        2118
# 7504  [like, congratulate, president, country, denma...        1160
# 7505  [would, like, begin, thanking, secretary-gener...        1197
# 7506  [allow, outset, extend, mr, mogens, lykketoft,...         903

# %% [markdown]
# # Using the counter

# %%
from collections import Counter
tokens = tokenize("She likes my cats and my cats like my sofa.") #tokenize the input string 
testcount= Counter(tokens) #counting frequency of each token
print(testcount) #printing the token frequencies
# Out:
# Counter({'my': 3, 'cats': 2, 'She': 1, 'likes': 1, 'and': 1, 'like': 1, 'sofa': 1})

# %% [markdown]
# # Current count

# %%
more_tokens = tokenize("She likes dogs and cats.")
testcount.update(more_tokens) #updating token frequency with new tokens
print(testcount) #printing the updating token
# Out:
# Counter({'my': 3, 'cats': 3, 'She': 2, 'likes': 2, 'and': 2, 'like': 1, 'sofa': 1, 'dogs': 1})

# %%
counter = Counter() #intializing counter object
df['tokens'].map(counter.update) # Update the Counter with token frequencies column in the DataFrame
print(counter.most_common(5))#printing 5most common tokens
# Out:
# [('nations', 124508), ('united', 120763), ('international', 117223), ('world', 89421), ('countries', 85734)]

# %% [markdown]
# # Word frequency in its own dataframe

# %%
freq_df = pd.DataFrame.from_dict(counter,
orient='index', columns=['freq']) #converting counter object to dataframe
freq_df = freq_df.query('freq >= 1') #filtering tokens with frequency less than equal to 1
freq_df.index.name = 'token' #set index name dataframe to 'token'

# %% [markdown]
# # Sort and Display

# %%
freq_df = freq_df.sort_values('freq', ascending=False) #sort the dataframe to descending order
freq_df.head(10) #displaying top 10 frequencies
# Out:
#                  freq
# token
# nations        124508
# united         120763
# international  117223
# world           89421
# countries       85734
# peace           72625
# development     62632
# states          59713
# people          59338
# security        58425

# %% [markdown]
# # Stats

# %%
freq_df.describe() #creating frequency distribution's descriptive statistics.
# Out:
#                 freq
# count   68302.000000
# mean      162.686276
# std      1544.080072
# min         1.000000
# 25%         1.000000
# 50%         2.000000
# 75%        15.000000
# max    124508.000000

# %% [markdown]
# # Bar chart

# %%
ax = freq_df.head(15).plot(kind='barh', width=0.95, figsize=(12,8)) #plot top 15 most frequency tokens
ax.invert_yaxis() # Invert the y-axis to display the most frequent tokens 
ax.set(xlabel='Frequency', ylabel='Token', title='Top Words')# Set the labels and title for the plot
# Out:
# [Text(0.5, 0, 'Frequency'), Text(0, 0.5, 'Token'), Text(0.5, 1.0, 'Top Words')]

# %% [markdown]
# # Installing wordcloud

# %%
pip install wordcloud #installing wordcloud package using pip
# Out:
# Requirement already satisfied: wordcloud in c:\users\ramachandraiah\anaconda3\lib\site-packages (1.9.3)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: numpy>=1.6.1 in c:\users\ramachandraiah\anaconda3\lib\site-packages (from wordcloud) (1.24.3)
# Requirement already satisfied: pillow in c:\users\ramachandraiah\anaconda3\lib\site-packages (from wordcloud) (9.4.0)
# Requirement already satisfied: matplotlib in c:\users\ramachandraiah\anaconda3\lib\site-packages (from wordcloud) (3.7.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\ramachandraiah\anaconda3\lib\site-packages (from matplotlib->wordcloud) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\ramachandraiah\anaconda3\lib\site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\ramachandraiah\anaconda3\lib\site-packages (from matplotlib->wordcloud) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\ramachandraiah\anaconda3\lib\site-packages (from matplotlib->wordcloud) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\ramachandraiah\anaconda3\lib\site-packages (from matplotlib->wordcloud) (23.1)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in c:\users\ramachandraiah\anaconda3\lib\site-packages (from matplotlib->wordcloud) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\ramachandraiah\anaconda3\lib\site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\ramachandraiah\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)

# %% [markdown]
# # Word cloud

# %%
from wordcloud import WordCloud
from matplotlib import pyplot as plt #importing libraries
text = df.query("year==2015 and country=='USA'")['text'].values[0] # Filtering text data for the year 2015 and country USA
plt.figure(figsize=(14, 7)) # Set the figure size
wc = WordCloud(max_words=100, stopwords=stopwords) # Creating a WordCloud object 
wc.generate(text) # Generate the word cloud
plt.imshow(wc, interpolation='bilinear') # Display the word cloud using matplotlib
plt.axis("off") # turn off axis
# Out:
# (-0.5, 399.5, 199.5, -0.5)

# %%
wc = WordCloud(background_color='white', width = 300, height=300,max_words=100, margin=2) #creating wordcloud object using specific parameters
wc.fit_words(freq_df['freq'].to_dict() ) # Fit the word frequencies to the WordCloud object
plt.figure(figsize = (8, 8), facecolor = None) # Setting the figure size and background color
plt.imshow(wc) # Display the word cloud using matplotlib
plt.axis("off") # turn off the axis
plt.tight_layout(pad = 0) # adjust the layout
plt.show() # show the plot
