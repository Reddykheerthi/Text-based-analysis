# %% [markdown]
# # Description

# %% [raw]
# Using nltk importing stopwords and we can remove stop words for speed.
# cosine_distance helps to find the similarity between two vectors.
# networkx is used for the creation, manipulation, and study of complex networks or graphs.
# reading the text files.
# step-2 to find similarity between two sentences.
# build the vector for the first sentence.
# build the vector for the second sentence.
# Step 3 - Rank sentences in similarity martix.
# Finish off by printing summary.

# %% [markdown]
# # Import needed modules

# %%
#you can remove stop words for speed
from nltk.corpus import stopwords 
# Helps to find the similarity between two vectors.
from nltk.cluster.util import cosine_distance 
import numpy as np
# used for the creation, manipulation, and study of complex networks or graphs.
import networkx as nx

# %% [markdown]
# # Open file and split into sentences

# %%
textfiles = [
    r"C:\Users\Ramachandraiah\Downloads\Text1.txt",
    r"C:\Users\Ramachandraiah\Downloads\Text2.txt",
    r"C:\Users\Ramachandraiah\Downloads\Text3.txt",
    r"C:\Users\Ramachandraiah\Downloads\Text4.txt",
    r"C:\Users\Ramachandraiah\Downloads\Text5.txt"
]

# Create lists to hold sentences for each file
sentences_lists = [[] for _ in range(len(textfiles))]

for index, filepath in enumerate(textfiles):
    with open(filepath, "r") as file:
        # This file contains one paragraph of multiple sentences
        filedata = file.readline().strip()  # Read only the first line (paragraph)
        article = filedata.split(". ")  # Split paragraph into sentences
        for sentence in article:
            sentences_lists[index].append(sentence.replace("[^a-zA-Z]", " ").split(" "))

# %%
sentences_lists
# Out:
# [[['It', 'was', 'the', 'best', 'of', 'times'],
#   ['It', 'was', 'the', 'worst', 'of', 'times'],
#   ['It', 'was', 'the', 'age', 'of', 'wisdom'],
#   ['It', 'was', 'the', 'age', 'of', 'foolishness'],
#   ['What', 'is', 'the', 'importance', 'of', 'age'],
#   ['This', 'is', 'the', 'best', 'example.']],
#  [['I', 'AM', 'SAM'],
#   ['I', 'AM', 'SAM'],
#   ['SAM', 'I', 'AM'],
#   ['THAT', 'SAM-I-AM!', 'THAT', 'SAM-I-AM!'],
#   ['I', 'DO', 'NOT', 'LIKE', 'THAT', 'SAM-I-AM!'],
#   ['DO', 'WOULD', 'YOU', 'LIKE', 'GREEN', 'EGGS', 'AND', 'HAM?'],
#   ['I', 'DO', 'NOT', 'LIKE', 'THEM,', 'SAM-I-AM'],
#   ['I', 'DO', 'NOT', 'LIKE', 'GREEN', 'EGGS', 'AND', 'HAM'],
#   ['WOULD', 'YOU', 'LIKE', 'THEM', 'HERE', 'OR', 'THERE?'],
#   ['I', 'WOULD', 'NOT', 'LIKE', 'THEM', 'HERE', 'OR', 'THERE'],
#   ['I', 'WOULD', 'NOT', 'LIKE', 'THEM', 'ANYWHERE'],
#   ['I', 'DO', 'NOT', 'LIKE', 'GREEN', 'EGGS', 'AND', 'HAM'],
#   ['I', 'DO', 'NOT', 'LIKE', 'THEM,', 'SAM-I-AM'],
#   ['WOULD', 'YOU', 'LIKE', 'THEM', 'IN', 'A', 'HOUSE?'],
#   ['WOULD', 'YOU', 'LIKE', 'THEN', 'WITH', 'A', 'MOUSE?'],
#   ['I', 'DO', 'NOT', 'LIKE', 'THEM', 'IN', 'A', 'HOUSE'],
#   ['I', 'DO', 'NOT', 'LIKE', 'THEM', 'WITH', 'A', 'MOUSE'],
#   ['I', 'DO', 'NOT', 'LIKE', 'THEM', 'HERE', 'OR', 'THERE'],
#   ['I', 'DO', 'NOT', 'LIKE', 'THEM', 'ANYWHERE'],
#   ['I', 'DO', 'NOT', 'LIKE', 'GREEN', 'EGGS', 'AND', 'HAM'],
#   ['I', 'DO', 'NOT', 'LIKE', 'THEM,', 'SAM-I-AM.']],
#  [['As',
#    'an',
#    'institution',
#    'of',
#    'higher',
#    'learning,',
#    'Sacred',
#    'Heart',
#    'University',
#    'places',
#    'special',
#    'emphasis',
#    'on',
#    'academic',
#    'integrity,',
#    'which',
#    'is',
#    'a',
#    'commitment',
#    'to',
#    'the',
#    'fundamental',
#    'values',
#    'of',
#    'honesty,',
#    'trust,',
#    'fairness,',
#    'respect,',
#    'and',
#    'responsibility'],
#   ['Only',
#    'when',
#    'these',
#    'values',
#    'are',
#    'widely',
#    'respected',
#    'and',
#    'practiced',
#    'by',
#    'all',
#    'members',
#    'of',
#    'the',
#    'University',
#    'students,',
#    'faculty,',
#    'administrators,',
#    'and',
#    'staff',
#    'can',
#    'the',
#    'University',
#    'maintain',
#    'a',
#    'culture',
#    'that',
#    'promotes',
#    'free',
#    'exploration',
#    'of',
#    'knowledge,',
#    'constructive',
#    'debate,',
#    'genuine',
#    'learning,',
#    'effective',
#    'research,',
#    'fair',
#    'assessment',
#    'of',
#    'student',
#    'progress,',
#    'and',
#    'development',
#    'of',
#    'members',
#    'characters'],
#   ['These',
#    'aims',
#    'of',
#    'the',
#    'University',
#    'require',
#    'that',
#    'its',
#    'members',
#    'exercise',
#    'mutual',
#    'responsibilities'],
#   ['At',
#    'its',
#    'core,',
#    'academic',
#    'integrity',
#    'is',
#    'secured',
#    'by',
#    'a',
#    'principled',
#    'commitment',
#    'to',
#    'carry',
#    'out',
#    'these',
#    'responsibilities,',
#    'not',
#    'by',
#    'rules',
#    'and',
#    'penalties'],
#   ['Students',
#    'and',
#    'faculty',
#    'should',
#    'strive',
#    'to',
#    'create',
#    'an',
#    'academic',
#    'environment',
#    'that',
#    'is',
#    'honest,',
#    'fair,',
#    'and',
#    'respectful',
#    'of',
#    'all'],
#   ['They',
#    'do',
#    'this',
#    'by',
#    'evaluating',
#    'others',
#    'work',
#    'fairly,',
#    'by',
#    'responding',
#    'to',
#    'others',
#    'ideas',
#    'critically',
#    'yet',
#    'courteously,',
#    'by',
#    'respecting',
#    'others',
#    'intellectual',
#    'and',
#    'physical',
#    'property,',
#    'and',
#    'by',
#    'nurturing',
#    'the',
#    'values',
#    'of',
#    'academic',
#    'integrity',
#    'in',
#    'all',
#    'contexts',
#    'of',
#    'University',
#    'life'],
#   ['Appropriate',
#    'disciplinary',
#    'action',
#    'will',
#    'be',
#    'taken',
#    'for',
#    'violations',
#    'of',
#    'academic',
#    'integrity,',
#    'including',
#    'plagiarism,',
#    'cheating,',
#    'any',
#    'use',
#    'of',
#    'materials',
#    'for',
#    'an',
#    'assignment',
#    'or',
#    'exam',
#    'that',
#    'is',
#    'not',
#    'permitted',
#    'by',
#    'the',
#    'instructor,',
#    'and',
#    'theft',
#    'or',
#    'mutilation',
#    'of',
#    'intellectual',
#    'materials',
#    'or',
#    'other',
#    'University',
#    'equipment'],
#   ['Faculty',
#    'will',
#    'assign',
#    'failing',
#    'grades',
#    'for',
#    'violations',
#    'of',
#    'the',
#    'University',
#    'policy',
#    'on',
#    'academic',
#    'integrity',
#    'and',
#    'students',
#    'may',
#    'immediately',
#    'receive',
#    'an',
#    'F',
#    'for',
#    'a',
#    'course',
#    'in',
#    'which',
#    'they',
#    'commit',
#    'a',
#    'violation'],
#   ['Violations',
#    'of',
#    'academic',
#    'integrity',
#    'are',
#    'kept',
#    'on',
#    'file',
#    'second',
#    'violations',
#    'will',
#    'bring',
#    'additional',
#    'sanctions,',
#    'up',
#    'to',
#    'dismissal',
#    'from',
#    'the',
#    'University'],
#   ['For',
#    'any',
#    'disciplinary',
#    'action,',
#    'the',
#    'University',
#    'affords',
#    'the',
#    'student',
#    'the',
#    'right',
#    'of',
#    'due',
#    'process',
#    'in',
#    'an',
#    'appeals',
#    'procedure'],
#   ['All',
#    'matriculated',
#    'students',
#    'will',
#    'be',
#    'provided',
#    'with',
#    'a',
#    'full',
#    'description',
#    'of',
#    'the',
#    'University',
#    'standards',
#    'for',
#    'academic',
#    'integrity,',
#    'consequences',
#    'for',
#    'violations,',
#    'and',
#    'the',
#    'appeals',
#    'procedure.']],
#  [['Imagine', "there's", 'no', 'heaven'],
#   ["It's", 'easy', 'if', 'you', 'try'],
#   ['No', 'hell', 'below', 'us'],
#   ['Above', 'us,', 'only', 'sky'],
#   ['Imagine', 'all', 'the', 'people', "livin'", 'for', 'today'],
#   ['Imagine', "there's", 'no', 'countries'],
#   ['It', "isn't", 'hard', 'to', 'do'],
#   ['Nothing',
#    'to',
#    'kill',
#    'or',
#    'die',
#    'for',
#    'and',
#    'no',
#    'religion,',
#    'too'],
#   ['Imagine', 'all', 'the', 'people', "livin'", 'life', 'in', 'peace'],
#   ['You',
#    'may',
#    'say',
#    "I'm",
#    'a',
#    'dreamer',
#    'but',
#    "I'm",
#    'not',
#    'the',
#    'only',
#    'one'],
#   ['I',
#    'hope',
#    'someday',
#    "you'll",
#    'join',
#    'us',
#    'and',
#    'the',
#    'world',
#    'will',
#    'be',
#    'as',
#    'one'],
#   ['Imagine', 'no', 'possessions'],
#   ['I', 'wonder', 'if', 'you', 'can'],
#   ['No', 'need', 'for', 'greed', 'or', 'hunger'],
#   ['A', 'brotherhood', 'of', 'man'],
#   ['Imagine', 'all', 'the', 'people', 'sharing', 'all', 'the', 'world.']],
#  [['In',
#    'an',
#    'attempt',
#    'to',
#    'build',
#    'an',
#    'AI-ready',
#    'workforce,',
#    'Microsoft',
#    'announced',
#    'Intelligent',
#    'Cloud',
#    'Hub',
#    'which',
#    'has',
#    'been',
#    'launched',
#    'to',
#    'empower',
#    'the',
#    'next',
#    'generation',
#    'of',
#    'students',
#    'with',
#    'AI-ready',
#    'skills'],
#   ['Envisioned',
#    'as',
#    'a',
#    'three-year',
#    'collaborative',
#    'program,',
#    'Intelligent',
#    'Cloud',
#    'Hub',
#    'will',
#    'support',
#    'around',
#    '100',
#    'institutions',
#    'with',
#    'AI',
#    'infrastructure,',
#    'course',
#    'content',
#    'and',
#    'curriculum,',
#    'developer',
#    'support,',
#    'development',
#    'tools',
#    'and',
#    'give',
#    'students',
#    'access',
#    'to',
#    'cloud',
#    'and',
#    'AI',
#    'services'],
#   ['As',
#    'part',
#    'of',
#    'the',
#    'program,',
#    'the',
#    'Redmond',
#    'giant',
#    'which',
#    'wants',
#    'to',
#    'expand',
#    'its',
#    'reach',
#    'and',
#    'is',
#    'planning',
#    'to',
#    'build',
#    'a',
#    'strong',
#    'developer',
#    'ecosystem',
#    'in',
#    'India',
#    'with',
#    'the',
#    'program',
#    'will',
#    'set',
#    'up',
#    'the',
#    'core',
#    'AI',
#    'infrastructure',
#    'and',
#    'IoT',
#    'Hub',
#    'for',
#    'the',
#    'selected',
#    'campuses'],
#   ['The',
#    'company',
#    'will',
#    'provide',
#    'AI',
#    'development',
#    'tools',
#    'and',
#    'Azure',
#    'AI',
#    'services',
#    'such',
#    'as',
#    'Microsoft',
#    'Cognitive',
#    'Services,',
#    'Bot',
#    'Services',
#    'and',
#    'Azure',
#    'Machine',
#    'Learning.According',
#    'to',
#    'Manish',
#    'Prakash,',
#    'Country',
#    'General',
#    'Manager-PS,',
#    'Health',
#    'and',
#    'Education,',
#    'Microsoft',
#    'India,',
#    'said,',
#    '"With',
#    'AI',
#    'being',
#    'the',
#    'defining',
#    'technology',
#    'of',
#    'our',
#    'time,',
#    'it',
#    'is',
#    'transIn',
#    'an',
#    'attempt',
#    'to',
#    'build',
#    'an',
#    'AI-ready',
#    'workforce,',
#    'Microsoft',
#    'announced',
#    'Intelligent',
#    'Cloud',
#    'Hub',
#    'which',
#    'has',
#    'been',
#    'launched',
#    'to',
#    'empower',
#    'the',
#    'next',
#    'generation',
#    'of',
#    'students',
#    'with',
#    'AI-ready',
#    'skills'],
#   ['Envisioned',
#    'as',
#    'a',
#    'three-year',
#    'collaborative',
#    'program,',
#    'Intelligent',
#    'Cloud',
#    'Hub',
#    'will',
#    'support',
#    'around',
#    '100',
#    'institutions',
#    'with',
#    'AI',
#    'infrastructure,',
#    'course',
#    'content',
#    'and',
#    'curriculum,',
#    'developer',
#    'support,',
#    'development',
#    'tools',
#    'and',
#    'give',
#    'students',
#    'access',
#    'to',
#    'cloud',
#    'and',
#    'AI',
#    'services'],
#   ['As',
#    'part',
#    'of',
#    'the',
#    'program,',
#    'the',
#    'Redmond',
#    'giant',
#    'which',
#    'wants',
#    'to',
#    'expand',
#    'its',
#    'reach',
#    'and',
#    'is',
#    'planning',
#    'to',
#    'build',
#    'a',
#    'strong',
#    'developer',
#    'ecosystem',
#    'in',
#    'India',
#    'with',
#    'the',
#    'program',
#    'will',
#    'set',
#    'up',
#    'the',
#    'core',
#    'AI',
#    'infrastructure',
#    'and',
#    'IoT',
#    'Hub',
#    'for',
#    'the',
#    'selected',
#    'campuses'],
#   ['The',
#    'company',
#    'will',
#    'provide',
#    'AI',
#    'development',
#    'tools',
#    'and',
#    'Azure',
#    'AI',
#    'services',
#    'such',
#    'as',
#    'Microsoft',
#    'Cognitive',
#    'Services,',
#    'Bot',
#    'Services',
#    'and',
#    'Azure',
#    'Machine',
#    'Learning.According',
#    'to',
#    'Manish',
#    'Prakash,',
#    'Country',
#    'General',
#    'Manager-PS,',
#    'Health',
#    'and',
#    'Education,',
#    'Microsoft',
#    'India,',
#    'said,',
#    '"With',
#    'AI',
#    'being',
#    'the',
#    'defining',
#    'technology',
#    'of',
#    'our',
#    'time,',
#    'it',
#    'is',
#    'transforming',
#    'lives',
#    'and',
#    'industry',
#    'and',
#    'the',
#    'jobs',
#    'of',
#    'tomorrow',
#    'will',
#    'require',
#    'a',
#    'different',
#    'skillset'],
#   ['This',
#    'will',
#    'require',
#    'more',
#    'collaborations',
#    'and',
#    'training',
#    'and',
#    'working',
#    'with',
#    'AI'],
#   ['Thatâ€™s',
#    'why',
#    'it',
#    'has',
#    'become',
#    'more',
#    'critical',
#    'than',
#    'ever',
#    'for',
#    'educational',
#    'institutions',
#    'to',
#    'integrate',
#    'new',
#    'cloud',
#    'and',
#    'AI',
#    'technologies'],
#   ['The',
#    'program',
#    'is',
#    'an',
#    'attempt',
#    'to',
#    'ramp',
#    'up',
#    'the',
#    'institutional',
#    'set-up',
#    'and',
#    'build',
#    'capabilities',
#    'among',
#    'the',
#    'educators',
#    'to',
#    'educate',
#    'the',
#    'workforce',
#    'of',
#    'tomorrow."',
#    'The',
#    'program',
#    'aims',
#    'to',
#    'build',
#    'up',
#    'the',
#    'cognitive',
#    'skills',
#    'and',
#    'in-depth',
#    'understanding',
#    'of',
#    'developing',
#    'intelligent',
#    'cloud',
#    'connected',
#    'solutions',
#    'for',
#    'applications',
#    'across',
#    'industry'],
#   ['Earlier',
#    'in',
#    'April',
#    'this',
#    'year,',
#    'the',
#    'company',
#    'announced',
#    'Microsoft',
#    'Professional',
#    'Program',
#    'In',
#    'AI',
#    'as',
#    'a',
#    'learning',
#    'track',
#    'open',
#    'to',
#    'the',
#    'public'],
#   ['The',
#    'program',
#    'was',
#    'developed',
#    'to',
#    'provide',
#    'job',
#    'ready',
#    'skills',
#    'to',
#    'programmers',
#    'who',
#    'wanted',
#    'to',
#    'hone',
#    'their',
#    'skills',
#    'in',
#    'AI',
#    'and',
#    'data',
#    'science',
#    'with',
#    'a',
#    'series',
#    'of',
#    'online',
#    'courses',
#    'which',
#    'featured',
#    'hands-on',
#    'labs',
#    'and',
#    'expert',
#    'instructors',
#    'as',
#    'well'],
#   ['This',
#    'program',
#    'also',
#    'included',
#    'developer-focused',
#    'AI',
#    'school',
#    'that',
#    'provided',
#    'a',
#    'bunch',
#    'of',
#    'assets',
#    'to',
#    'help',
#    'build',
#    'AI',
#    'skills.']]]

# %%
for i in range(len(sentences_lists)):
    print(f'-------------Text{i}--------------')
    print(' '*10)
    print(sentences_lists[i])
    print(' '*10)
# Out:
# -------------Text0--------------
#
# [['It', 'was', 'the', 'best', 'of', 'times'], ['It', 'was', 'the', 'worst', 'of', 'times'], ['It', 'was', 'the', 'age', 'of', 'wisdom'], ['It', 'was', 'the', 'age', 'of', 'foolishness'], ['What', 'is', 'the', 'importance', 'of', 'age'], ['This', 'is', 'the', 'best', 'example.']]
#
# -------------Text1--------------
#
# [['I', 'AM', 'SAM'], ['I', 'AM', 'SAM'], ['SAM', 'I', 'AM'], ['THAT', 'SAM-I-AM!', 'THAT', 'SAM-I-AM!'], ['I', 'DO', 'NOT', 'LIKE', 'THAT', 'SAM-I-AM!'], ['DO', 'WOULD', 'YOU', 'LIKE', 'GREEN', 'EGGS', 'AND', 'HAM?'], ['I', 'DO', 'NOT', 'LIKE', 'THEM,', 'SAM-I-AM'], ['I', 'DO', 'NOT', 'LIKE', 'GREEN', 'EGGS', 'AND', 'HAM'], ['WOULD', 'YOU', 'LIKE', 'THEM', 'HERE', 'OR', 'THERE?'], ['I', 'WOULD', 'NOT', 'LIKE', 'THEM', 'HERE', 'OR', 'THERE'], ['I', 'WOULD', 'NOT', 'LIKE', 'THEM', 'ANYWHERE'], ['I', 'DO', 'NOT', 'LIKE', 'GREEN', 'EGGS', 'AND', 'HAM'], ['I', 'DO', 'NOT', 'LIKE', 'THEM,', 'SAM-I-AM'], ['WOULD', 'YOU', 'LIKE', 'THEM', 'IN', 'A', 'HOUSE?'], ['WOULD', 'YOU', 'LIKE', 'THEN', 'WITH', 'A', 'MOUSE?'], ['I', 'DO', 'NOT', 'LIKE', 'THEM', 'IN', 'A', 'HOUSE'], ['I', 'DO', 'NOT', 'LIKE', 'THEM', 'WITH', 'A', 'MOUSE'], ['I', 'DO', 'NOT', 'LIKE', 'THEM', 'HERE', 'OR', 'THERE'], ['I', 'DO', 'NOT', 'LIKE', 'THEM', 'ANYWHERE'], ['I', 'DO', 'NOT', 'LIKE', 'GREEN', 'EGGS', 'AND', 'HAM'], ['I', 'DO', 'NOT', 'LIKE', 'THEM,', 'SAM-I-AM.']]
#
# -------------Text2--------------
#
# [['As', 'an', 'institution', 'of', 'higher', 'learning,', 'Sacred', 'Heart', 'University', 'places', 'special', 'emphasis', 'on', 'academic', 'integrity,', 'which', 'is', 'a', 'commitment', 'to', 'the', 'fundamental', 'values', 'of', 'honesty,', 'trust,', 'fairness,', 'respect,', 'and', 'responsibility'], ['Only', 'when', 'these', 'values', 'are', 'widely', 'respected', 'and', 'practiced', 'by', 'all', 'members', 'of', 'the', 'University', 'students,', 'faculty,', 'administrators,', 'and', 'staff', 'can', 'the', 'University', 'maintain', 'a', 'culture', 'that', 'promotes', 'free', 'exploration', 'of', 'knowledge,', 'constructive', 'debate,', 'genuine', 'learning,', 'effective', 'research,', 'fair', 'assessment', 'of', 'student', 'progress,', 'and', 'development', 'of', 'members', 'characters'], ['These', 'aims', 'of', 'the', 'University', 'require', 'that', 'its', 'members', 'exercise', 'mutual', 'responsibilities'], ['At', 'its', 'core,', 'academic', 'integrity', 'is', 'secured', 'by', 'a', 'principled', 'commitment', 'to', 'carry', 'out', 'these', 'responsibilities,', 'not', 'by', 'rules', 'and', 'penalties'], ['Students', 'and', 'faculty', 'should', 'strive', 'to', 'create', 'an', 'academic', 'environment', 'that', 'is', 'honest,', 'fair,', 'and', 'respectful', 'of', 'all'], ['They', 'do', 'this', 'by', 'evaluating', 'others', 'work', 'fairly,', 'by', 'responding', 'to', 'others', 'ideas', 'critically', 'yet', 'courteously,', 'by', 'respecting', 'others', 'intellectual', 'and', 'physical', 'property,', 'and', 'by', 'nurturing', 'the', 'values', 'of', 'academic', 'integrity', 'in', 'all', 'contexts', 'of', 'University', 'life'], ['Appropriate', 'disciplinary', 'action', 'will', 'be', 'taken', 'for', 'violations', 'of', 'academic', 'integrity,', 'including', 'plagiarism,', 'cheating,', 'any', 'use', 'of', 'materials', 'for', 'an', 'assignment', 'or', 'exam', 'that', 'is', 'not', 'permitted', 'by', 'the', 'instructor,', 'and', 'theft', 'or', 'mutilation', 'of', 'intellectual', 'materials', 'or', 'other', 'University', 'equipment'], ['Faculty', 'will', 'assign', 'failing', 'grades', 'for', 'violations', 'of', 'the', 'University', 'policy', 'on', 'academic', 'integrity', 'and', 'students', 'may', 'immediately', 'receive', 'an', 'F', 'for', 'a', 'course', 'in', 'which', 'they', 'commit', 'a', 'violation'], ['Violations', 'of', 'academic', 'integrity', 'are', 'kept', 'on', 'file', 'second', 'violations', 'will', 'bring', 'additional', 'sanctions,', 'up', 'to', 'dismissal', 'from', 'the', 'University'], ['For', 'any', 'disciplinary', 'action,', 'the', 'University', 'affords', 'the', 'student', 'the', 'right', 'of', 'due', 'process', 'in', 'an', 'appeals', 'procedure'], ['All', 'matriculated', 'students', 'will', 'be', 'provided', 'with', 'a', 'full', 'description', 'of', 'the', 'University', 'standards', 'for', 'academic', 'integrity,', 'consequences', 'for', 'violations,', 'and', 'the', 'appeals', 'procedure.']]
#
# -------------Text3--------------
#
# [['Imagine', "there's", 'no', 'heaven'], ["It's", 'easy', 'if', 'you', 'try'], ['No', 'hell', 'below', 'us'], ['Above', 'us,', 'only', 'sky'], ['Imagine', 'all', 'the', 'people', "livin'", 'for', 'today'], ['Imagine', "there's", 'no', 'countries'], ['It', "isn't", 'hard', 'to', 'do'], ['Nothing', 'to', 'kill', 'or', 'die', 'for', 'and', 'no', 'religion,', 'too'], ['Imagine', 'all', 'the', 'people', "livin'", 'life', 'in', 'peace'], ['You', 'may', 'say', "I'm", 'a', 'dreamer', 'but', "I'm", 'not', 'the', 'only', 'one'], ['I', 'hope', 'someday', "you'll", 'join', 'us', 'and', 'the', 'world', 'will', 'be', 'as', 'one'], ['Imagine', 'no', 'possessions'], ['I', 'wonder', 'if', 'you', 'can'], ['No', 'need', 'for', 'greed', 'or', 'hunger'], ['A', 'brotherhood', 'of', 'man'], ['Imagine', 'all', 'the', 'people', 'sharing', 'all', 'the', 'world.']]
#
# -------------Text4--------------
#
# [['In', 'an', 'attempt', 'to', 'build', 'an', 'AI-ready', 'workforce,', 'Microsoft', 'announced', 'Intelligent', 'Cloud', 'Hub', 'which', 'has', 'been', 'launched', 'to', 'empower', 'the', 'next', 'generation', 'of', 'students', 'with', 'AI-ready', 'skills'], ['Envisioned', 'as', 'a', 'three-year', 'collaborative', 'program,', 'Intelligent', 'Cloud', 'Hub', 'will', 'support', 'around', '100', 'institutions', 'with', 'AI', 'infrastructure,', 'course', 'content', 'and', 'curriculum,', 'developer', 'support,', 'development', 'tools', 'and', 'give', 'students', 'access', 'to', 'cloud', 'and', 'AI', 'services'], ['As', 'part', 'of', 'the', 'program,', 'the', 'Redmond', 'giant', 'which', 'wants', 'to', 'expand', 'its', 'reach', 'and', 'is', 'planning', 'to', 'build', 'a', 'strong', 'developer', 'ecosystem', 'in', 'India', 'with', 'the', 'program', 'will', 'set', 'up', 'the', 'core', 'AI', 'infrastructure', 'and', 'IoT', 'Hub', 'for', 'the', 'selected', 'campuses'], ['The', 'company', 'will', 'provide', 'AI', 'development', 'tools', 'and', 'Azure', 'AI', 'services', 'such', 'as', 'Microsoft', 'Cognitive', 'Services,', 'Bot', 'Services', 'and', 'Azure', 'Machine', 'Learning.According', 'to', 'Manish', 'Prakash,', 'Country', 'General', 'Manager-PS,', 'Health', 'and', 'Education,', 'Microsoft', 'India,', 'said,', '"With', 'AI', 'being', 'the', 'defining', 'technology', 'of', 'our', 'time,', 'it', 'is', 'transIn', 'an', 'attempt', 'to', 'build', 'an', 'AI-ready', 'workforce,', 'Microsoft', 'announced', 'Intelligent', 'Cloud', 'Hub', 'which', 'has', 'been', 'launched', 'to', 'empower', 'the', 'next', 'generation', 'of', 'students', 'with', 'AI-ready', 'skills'], ['Envisioned', 'as', 'a', 'three-year', 'collaborative', 'program,', 'Intelligent', 'Cloud', 'Hub', 'will', 'support', 'around', '100', 'institutions', 'with', 'AI', 'infrastructure,', 'course', 'content', 'and', 'curriculum,', 'developer', 'support,', 'development', 'tools', 'and', 'give', 'students', 'access', 'to', 'cloud', 'and', 'AI', 'services'], ['As', 'part', 'of', 'the', 'program,', 'the', 'Redmond', 'giant', 'which', 'wants', 'to', 'expand', 'its', 'reach', 'and', 'is', 'planning', 'to', 'build', 'a', 'strong', 'developer', 'ecosystem', 'in', 'India', 'with', 'the', 'program', 'will', 'set', 'up', 'the', 'core', 'AI', 'infrastructure', 'and', 'IoT', 'Hub', 'for', 'the', 'selected', 'campuses'], ['The', 'company', 'will', 'provide', 'AI', 'development', 'tools', 'and', 'Azure', 'AI', 'services', 'such', 'as', 'Microsoft', 'Cognitive', 'Services,', 'Bot', 'Services', 'and', 'Azure', 'Machine', 'Learning.According', 'to', 'Manish', 'Prakash,', 'Country', 'General', 'Manager-PS,', 'Health', 'and', 'Education,', 'Microsoft', 'India,', 'said,', '"With', 'AI', 'being', 'the', 'defining', 'technology', 'of', 'our', 'time,', 'it', 'is', 'transforming', 'lives', 'and', 'industry', 'and', 'the', 'jobs', 'of', 'tomorrow', 'will', 'require', 'a', 'different', 'skillset'], ['This', 'will', 'require', 'more', 'collaborations', 'and', 'training', 'and', 'working', 'with', 'AI'], ['Thatâ€™s', 'why', 'it', 'has', 'become', 'more', 'critical', 'than', 'ever', 'for', 'educational', 'institutions', 'to', 'integrate', 'new', 'cloud', 'and', 'AI', 'technologies'], ['The', 'program', 'is', 'an', 'attempt', 'to', 'ramp', 'up', 'the', 'institutional', 'set-up', 'and', 'build', 'capabilities', 'among', 'the', 'educators', 'to', 'educate', 'the', 'workforce', 'of', 'tomorrow."', 'The', 'program', 'aims', 'to', 'build', 'up', 'the', 'cognitive', 'skills', 'and', 'in-depth', 'understanding', 'of', 'developing', 'intelligent', 'cloud', 'connected', 'solutions', 'for', 'applications', 'across', 'industry'], ['Earlier', 'in', 'April', 'this', 'year,', 'the', 'company', 'announced', 'Microsoft', 'Professional', 'Program', 'In', 'AI', 'as', 'a', 'learning', 'track', 'open', 'to', 'the', 'public'], ['The', 'program', 'was', 'developed', 'to', 'provide', 'job', 'ready', 'skills', 'to', 'programmers', 'who', ...

# %%
# step-2 to find similarity between two sentences 
def sentence_similarity(sent1, sent2 ):
    sent1 = [w.lower() for w in sent1]
    sent2 = [w.lower() for w in sent2]
    all_words = list(set(sent1 + sent2))
    vector1 = [0] * len(all_words)
    vector2 = [0] * len(all_words)
    # build the vector for the first sentence
    for w in sent1:
        vector1[all_words.index(w)] += 1
        # build the vector for the second sentence
    for w in sent2:
        vector2[all_words.index(w)] += 1
    return 1 - cosine_distance(vector1, vector2)

# %% [markdown]
# # Create the similarity matrix

# %%
import numpy as np
similarity=[]
for i in sentences_lists:
    similarity_matrix = np.zeros((len(i), len(i)))
    for idx1 in range(len(i)):
        for idx2 in range(len(i)):
            if idx1 == idx2: #ignore if both are same sentences
                continue
            similarity_matrix[idx1][idx2] = sentence_similarity(i[idx1], i[idx2])
    similarity.append(similarity_matrix)

# %%
similarity
# Out:
# [array([[0.        , 0.83333333, 0.66666667, 0.66666667, 0.33333333,
#          0.36514837],
#         [0.83333333, 0.        , 0.66666667, 0.66666667, 0.33333333,
#          0.18257419],
#         [0.66666667, 0.66666667, 0.        , 0.83333333, 0.5       ,
#          0.18257419],
#         [0.66666667, 0.66666667, 0.83333333, 0.        , 0.5       ,
#          0.18257419],
#         [0.33333333, 0.33333333, 0.5       , 0.5       , 0.        ,
#          0.        , 0.32090298, 0.26832816],
#         [0.33009387, 0.30785965, 0.412959  , 0.39970544, 0.30785965,
#          0.412959  , 0.34833862, 0.24273402, 0.20078234, 0.38227015,
#          0.32090298, 0.        , 0.26093123],
#         [0.15569979, 0.20225996, 0.22019275, 0.25354628, 0.20225996,
#          0.22019275, 0.22249708, 0.1860521 , 0.15389675, 0.21096325,
#          0.26832816, 0.26093123, 0.        ]])]

# %% [markdown]
# # Get the pagerank scores

# %%
# Step 3 - Rank sentences in similarity martix
score=[]
for i in similarity:
    sentence_similarity_graph = nx.from_numpy_array(i)
    scores = nx.pagerank(sentence_similarity_graph)
    score.append(scores)

# %%
score
# Out:
# [{0: 0.19306449754902083,
#   1: 0.18095893645850156,
#   2: 0.1911855225552033,
#   3: 0.1911855225552033,
#   4: 0.14434636291527997,
#   5: 0.09925915796679063},
#  {0: 0.03492638917817515,
#   1: 0.03492638917817515,
#   2: 0.03492638917817515,
#   3: 0.010552425887368076,
#   4: 0.06321847556853293,
#   5: 0.03960609463088077,
#   6: 0.057289451630209653,
#   7: 0.056226314678287335,
#   8: 0.03486412173792891,
#   9: 0.053338934277549654,
#   10: 0.0566062415473087,
#   11: 0.056226314678287335,
#   12: 0.05728945163020967,
#   13: 0.0350182718613405,
#   14: 0.02940805086606966,
#   15: 0.056983599690836606,
#   16: 0.05702071446687991,
#   17: 0.057531865612924,
#   18: 0.06143601920162538,
#   19: 0.056226314678287335,
#   20: 0.05637816982094812},
#  {0: 0.10052808533762261,
#   1: 0.1092617813187325,
#   2: 0.07743541734389628,
#   3: 0.06555131921078501,
#   4: 0.08353031285994028,
#   5: 0.09032582020361654,
#   6: 0.10094508912146115,
#   7: 0.10059598487085707,
#   8: 0.08058955768995534,
#   9: 0.08737172856802625,
#   10: 0.10386490347510732},
#  {0: 0.09299170149712502,
#   1: 0.044818539524156716,
#   2: 0.05529693532492523,
#   3: 0.018028858039734523,
#   4: 0.09732322936224566,
#   5: 0.09299170149712502,
#   6: 0.015101257665800345,
#   7: 0.0663515520482321,
#   8: 0.08321324188805862,
#   9: 0.07651835623030878,
#   10: 0.04893104927921404,
#   11: 0.09359906720760519,
#   12: 0.05243467813970095,
#   13: 0.058642705064067546,
#   14: 0.018028858039734523,
#   15: 0.08572826919196602},
#  {0: 0.06505377280671527,
#   1: 0.08331029356108051,
#   2: 0.0944374740565271,
#   3: 0.0984332545355071,
#   4: 0.08331029356108051,
#   5: 0.0944374740565271,
#   6: 0.08956736183704041,
#   7: 0.06144739693431779,
#   8: 0.05275205184695904,
#   9: 0.08067100597330357,
#   10: 0.0654765113515673,
#   11: 0.07702790911312701,
#   12: 0.054075200366247446}]

# %% [markdown]
# # Sort sentences by pagerank

# %%
ranked_sentences = []
for sentence_list in sentences_lists:
    ranked_sentence = sorted(((score, sentence) for score, sentence in zip(scores, sentence_list)), reverse=True)
    ranked_sentences.append(ranked_sentence)

# %%
ranked_sentences
# Out:
# [[(5, ['This', 'is', 'the', 'best', 'example.']),
#   (4, ['What', 'is', 'the', 'importance', 'of', 'age']),
#   (3, ['It', 'was', 'the', 'age', 'of', 'foolishness']),
#   (2, ['It', 'was', 'the', 'age', 'of', 'wisdom']),
#   (1, ['It', 'was', 'the', 'worst', 'of', 'times']),
#   (0, ['It', 'was', 'the', 'best', 'of', 'times'])],
#  [(12, ['I', 'DO', 'NOT', 'LIKE', 'THEM,', 'SAM-I-AM']),
#   (11, ['I', 'DO', 'NOT', 'LIKE', 'GREEN', 'EGGS', 'AND', 'HAM']),
#   (10, ['I', 'WOULD', 'NOT', 'LIKE', 'THEM', 'ANYWHERE']),
#   (9, ['I', 'WOULD', 'NOT', 'LIKE', 'THEM', 'HERE', 'OR', 'THERE']),
#   (8, ['WOULD', 'YOU', 'LIKE', 'THEM', 'HERE', 'OR', 'THERE?']),
#   (7, ['I', 'DO', 'NOT', 'LIKE', 'GREEN', 'EGGS', 'AND', 'HAM']),
#   (6, ['I', 'DO', 'NOT', 'LIKE', 'THEM,', 'SAM-I-AM']),
#   (5, ['DO', 'WOULD', 'YOU', 'LIKE', 'GREEN', 'EGGS', 'AND', 'HAM?']),
#   (4, ['I', 'DO', 'NOT', 'LIKE', 'THAT', 'SAM-I-AM!']),
#   (3, ['THAT', 'SAM-I-AM!', 'THAT', 'SAM-I-AM!']),
#   (2, ['SAM', 'I', 'AM']),
#   (1, ['I', 'AM', 'SAM']),
#   (0, ['I', 'AM', 'SAM'])],
#  [(10,
#    ['All',
#     'matriculated',
#     'students',
#     'will',
#     'be',
#     'provided',
#     'with',
#     'a',
#     'full',
#     'description',
#     'of',
#     'the',
#     'University',
#     'standards',
#     'for',
#     'academic',
#     'integrity,',
#     'consequences',
#     'for',
#     'violations,',
#     'and',
#     'the',
#     'appeals',
#     'procedure.']),
#   (9,
#    ['For',
#     'any',
#     'disciplinary',
#     'action,',
#     'the',
#     'University',
#     'affords',
#     'the',
#     'student',
#     'the',
#     'right',
#     'of',
#     'due',
#     'process',
#     'in',
#     'an',
#     'appeals',
#     'procedure']),
#   (8,
#    ['Violations',
#     'of',
#     'academic',
#     'integrity',
#     'are',
#     'kept',
#     'on',
#     'file',
#     'second',
#     'violations',
#     'will',
#     'bring',
#     'additional',
#     'sanctions,',
#     'up',
#     'to',
#     'dismissal',
#     'from',
#     'the',
#     'University']),
#   (7,
#    ['Faculty',
#     'will',
#     'assign',
#     'failing',
#     'grades',
#     'for',
#     'violations',
#     'of',
#     'the',
#     'University',
#     'policy',
#     'on',
#     'academic',
#     'integrity',
#     'and',
#     'students',
#     'may',
#     'immediately',
#     'receive',
#     'an',
#     'F',
#     'for',
#     'a',
#     'course',
#     'in',
#     'which',
#     'they',
#     'commit',
#     'a',
#     'violation']),
#   (6,
#    ['Appropriate',
#     'disciplinary',
#     'action',
#     'will',
#     'be',
#     'taken',
#     'for',
#     'violations',
#     'of',
#     'academic',
#     'integrity,',
#     'including',
#     'plagiarism,',
#     'cheating,',
#     'any',
#     'use',
#     'of',
#     'materials',
#     'for',
#     'an',
#     'assignment',
#     'or',
#     'exam',
#     'that',
#     'is',
#     'not',
#     'permitted',
#     'by',
#     'the',
#     'instructor,',
#     'and',
#     'theft',
#     'or',
#     'mutilation',
#     'of',
#     'intellectual',
#     'materials',
#     'or',
#     'other',
#     'University',
#     'equipment']),
#   (5,
#    ['They',
#     'do',
#     'this',
#     'by',
#     'evaluating',
#     'others',
#     'work',
#     'fairly,',
#     'by',
#     'responding',
#     'to',
#     'others',
#     'ideas',
#     'critically',
#     'yet',
#     'courteously,',
#     'by',
#     'respecting',
#     'others',
#     'intellectual',
#     'and',
#     'physical',
#     'property,',
#     'and',
#     'by',
#     'nurturing',
#     'the',
#     'values',
#     'of',
#     'academic',
#     'integrity',
#     'in',
#     'all',
#     'contexts',
#     'of',
#     'University',
#     'life']),
#   (4,
#    ['Students',
#     'and',
#     'faculty',
#     'should',
#     'strive',
#     'to',
#     'create',
#     'an',
#     'academic',
#     'environment',
#     'that',
#     'is',
#     'honest,',
#     'fair,',
#     'and',
#     'respectful',
#     'of',
#     'all']),
#   (3,
#    ['At',
#     'its',
#     'core,',
#     'academic',
#     'integrity',
#     'is',
#     'secured',
#     'by',
#     'a',
#     'principled',
#     'commitment',
#     'to',
#     'carry',
#     'out',
#     'these',
#     'responsibilities,',
#     'not',
#     'by',
#     'rules',
#     'and',
#     'penalties']),
#   (2,
#    ['These',
#     'aims',
#     'of',
#     'the',
#     'University',
#     'require',
#     'that',
#     'its',
#     'members',
#     'exercise',
#     'mutual',
#     'responsibilities']),
#   (1,
#    ['Only',
#     'when',
#     'these',
#     'values',
#     'are',
#     'widely',
#     'respected',
#     'and',
#     'practiced',
#     'by',
#     'all',
#     'members',
#     'of',
#     'the',
#     'University',
#     'students,',
#     'faculty,',
#     'administrators,',
#     'and',
#     'staff',
#     'can',
#     'the',
#     'University',
#     'maintain',
#     'a',
#     'culture',
#     'that',
#     'promotes',
#     'free',
#     'exploration',
#     'of',
#     'knowledge,',
#     'constructive',
#     'debate,',
#     'genuine',
#     'learning,',
#     'effective',
#     'research,',
#     'fair',
#     'assessment',
#     'of',
#     'student',
#     'progress,',
#     'and',
#     'development',
#     'of',
#     'members',
#     'characters']),
#   (0,
#    ['As',
#     'an',
#     'institution',
#     'of',
#     'higher',
#     'learning,',
#     'Sacred',
#     'Heart',
#     'University',
#     'places',
#     'special',
#     'emphasis',
#     'on',
#     'academic',
#     'integrity,',
#     'which',
#     'is',
#     'a',
#     'commitment',
#     'to',
#     'the',
#     'fundamental',
#     'values',
#     'of',
#     'honesty,',
#     'trust,',
#     'fairness,',
#     'respect,',
#     'and',
#     'responsibility'])],
#  [(12, ['I', 'wonder', 'if', 'you', 'can']),
#   (11, ['Imagine', 'no', 'possessions']),
#   (10,
#    ['I',
#     'hope',
#     'someday',
#     "you'll",
#     'join',
#     'us',
#     'and',
#     'the',
#     'world',
#     'will',
#     'be',
#     'as',
#     'one']),
#   (9,
#    ['You',
#     'may',
#     'say',
#     "I'm",
#     'a',
#     'dreamer',
#     'but',
#     "I'm",
#     'not',
#     'the',
#     'only',
#     'one']),
#   (8, ['Imagine', 'all', 'the', 'people', "livin'", 'life', 'in', 'peace']),
#   (7,
#    ['Nothing',
#     'to',
#     'kill',
#     'or',
#     'die',
#     'for',
#     'and',
#     'no',
#     'religion,',
#     'too']),
#   (6, ['It', "isn't", 'hard', 'to', 'do']),
#   (5, ['Imagine', "there's", 'no', 'countries']),
#   (4, ['Imagine', 'all', 'the', 'people', "livin'", 'for', 'today']),
#   (3, ['Above', 'us,', 'only', 'sky']),
#   (2, ['No', 'hell', 'below', 'us']),
#   (1, ["It's", 'easy', 'if', 'you', 'try']),
#   (0, ['Imagine', "there's", 'no', 'heaven'])],
#  [(12,
#    ['This',
#     'program',
#     'also',
#     'included',
#     'developer-focused',
#     'AI',
#     'school',
#     'that',
#     'provided',
#     'a',
#     'bunch',
#     'of',
#     'assets',
#     'to',
#     'help',
#     'build',
#     'AI',
#     'skills.']),
#   (11,
#    ['The',
#     'program',
#     'was',
#     'developed',
#     'to',
#     'provide',
#     'job',
#     'ready',
#     'skills',
#     'to',
#     'programmers',
#     'who',
#     'wanted',
#     'to',
#     'hone',
#     'their',
#     'skills',
#     'in',
#     'AI',
#     'and',
#     'data',
#     'science',
#     'with',
#     'a',
#     'series',
#     'of',
#     'online',
#     'courses',
#     'which',
#     'featured',
#     'hands-on',
#     'labs',
#     'and',
#     'expert',
#     'instructors',
#     'as',
#     'well']),
#   (10,
#    ['Earlier',
#     'in',
#     'April',
#     'this',
#     'year,',
#     'the',
#     'company',
#     'announced',
#     'Microsoft',
#     'Professional',
#     'Program',
#     'In',
#     'AI',
#     'as',
#     'a',
#     'learning',
#     'track',
#     'open',
#     'to',
#     'the',
#     'public']),
#   (9,
#    ['The',
#     'program',
#     'is',
#     'an',
#     'attempt',
#     'to',
#     'ramp',
#     'up',
#     'the',
#     'institutional',
#     'set-up',
#     'and',
#     'build',
#     'capabilities',
#     'among',
#     'the',
#     'educators',
#     'to',
#     'educate',
#     'the',
#     'workforce',
#     'of',
#     'tomorrow."',
#     'The',
#     'program',
#     'aims',
#     'to',
#     'build',
#     'up',
#     'the',
#     'cognitive',
#     'skills',
#     'and',
#     'in-depth',
#     'understanding',
#     'of',
#     'developing',
#     'intelligent',
#     'cloud',
#     'connected',
#     'solutions',
#     'for',
#     'applications',
#     'across',
#     'industry']),
#   (8,
#    ['Thatâ€™s',
#     'why',
#     'it',
#     'has',
#     'become',
#     'more',
#     'critical',
#     'than',
#     'ever',
#     'for',
#     'educational',
#     'institutions',
#     'to',
#     'integrate',
#     'new',
#     'cloud',
#     'and',
#     'AI',
#     'technologies']),
#   (7,
#    ['This',
#     'will',
#     'require',
#     'more',
#     'collaborations',
#     'and',
#     'training',
#     'and',
#     'working',
#     'with',
#     'AI']),
#   (6,
#    ['The',
#     'company',
#     'will',
#     'provide',
#     'AI',
#     'development',
#     'tools',
#     'and',
#     'Azure',
#     'AI',
#     'services',
#     'such',
#     'as',
#     'Microsoft',
#     'Cognitive',
#     'Services,',
#     'Bot',
#     'Services',
#     'and',
#     'Azure',
#     'Machine',
#     'Learning.According',
#     'to',
#     'Manish',
#     'Prakash,',
#     'Country',
#     'General',
#     'Manager-PS,',
#     'Health',
#     'and',
#     'Education,',
#     'Microsoft',
#     'India,',
#     'said,',
#     '"With',
#     'AI',
#     'being',
#     'the',
#     'defining',
#     'technology',
#     'of',
#     'our',
#     'time,',
#     'it',
#     'is',
#     'transforming',
#     'lives',
#     'and',
#     'industry',
#     'and',
#     'the',
#     'jobs',
#     'of',
#     'tomorrow',
#     'will',
#     'require',
#     'a',
#     'different',
#     'skillset']),
#   (5,
#    ['As',
#     'part',
#     'of',
#     'the',
#     'program,',
#     'the',
#     'Redmond',
#     'giant',
#     'which',
#     'wants',
#     'to',
#     'expand',
#     'its',
#     'reach',
#     'and',
#     'is',
#     'planning',
#     'to',
#     'build',
#     'a',
#     'strong',
#     'developer',
#     'ecosystem',
#     'in',
#     'India',
#     'with',
#     'the',
#     'program',
#     'will',
#     'set',
#     'up',
#     'the',
#     'core',
#     'AI',
#     'infrastructure',
#     'and',
#     'IoT',
#     'Hub',
#     'for',
#     'the',
#     'selected',
#     'campuses']),
#   (4,
#    ['Envisioned',
#     'as',
#     'a',
#     'three-year',
#     'collaborative',
#     'program,',
#     'Intelligent',
#     'Cloud',
#     'Hub',
#     'will',
#     'support',
#     'around',
#     '100',
#     'institutions',
#     'with',
#     'AI',
#     'infrastructure,',
#     'course',
#     'content',
#     'and',
#     'curriculum,',
#     'developer',
#     'support,',
#     'development',
#     'tools',
#     'and',
#     'give',
#     'students',
#     'access',
#     'to',
#     'cloud',
#     'and',
#     'AI',
#     'services']),
#   (3,
#    ['The',
#     'company',
#     'will',
#     'provide',
#     'AI',
#     'development',
#     'tools',
#     'and',
#     'Azure',
#     'AI',
#     'services',
#     'such',
#     'as',
#     'Microsoft',
#     'Cognitive',
#     'Services,',
#     'Bot',
#     'Services',
#     'and',
#     'Azure',
#     'Machine',
#     'Learning.According',
#     'to',
#     'Manish',
#     'Prakash,',
#     'Country',
#     'General',
#     'Manager-PS,',
#     'Health',
#     'and',
#     'Education,',
#     'Microsoft',
#     'India,',
#     'said,',
#     '"With',
#     'AI',
#     'being',
#     'the',
#     'defining',
#     'technology',
#     'of',
#     'our',
#     'time,',
#     'it',
#     'is',
#     'transIn',
#     'an',
#     'attempt',
#     'to',
#     'build',
#     'an',
#     'AI-ready',
#     'workforce,',
#     'Microsoft',
#     'announced',
#     'Intelligent',
#     'Cloud',
#     'Hub',
#     'which',
#     'has',
#     'been',
#     'launched',
#     'to',
#     'empower',
#     'the',
#     'next',
#     'generation',
#     'of',
#     'students',
#     'with',
#     'AI-ready',
#     'skills']),
#   (2,
#    ['As',
#     'part',
#     'of',
#     'the',
#     'program,',
#     'the',
#     'Redmond',
#     'giant',
#     'which',
#     'wants',
#     'to',
#     'expand',
#     'its',
#     'reach',
#     'and',
#     'is',
#     'planning',
#     'to',
#     'build',
#     'a',
#     'strong',
#     'developer',
#     'ecosystem',
#     'in',
#     'India',
#     'with',
#     'the',
#     'program',
#     'will',
#     'set',
#     'up',
#     'the',
#     'core',
#     'AI',
#     'infrastructure',
#     'and',
#     'IoT',
#     'Hub',
#     'for',
#     'the',
#     'selected',
#     'campuses']),
#   (1,
#    ['Envisioned',
#     'as',
#     'a',
#     'three-year',
#     'collaborative',
#     'program,',
#     'Intelligent',
#     'Cloud',
#     'Hub',
#     'will',
#     'support',
#     'around',
#     '100',
#     'institutions',
#     'with',
#     'AI',
#     'infrastructure,',
#     'course',
#     'content',
#     'and',
#     'curriculum,',
#     'developer',
#     'support,',
#     'development',
#     'tools',
#     'and',
#     'give',
#     'students',
#     'access',
#     'to',
#     'cloud',
#     'and',
#     'AI',
#     'services']),
#   (0,
#    ['In',
#     'an',
#     'attempt',
#     'to',
#     'build',
#     'an',
#     'AI-ready',
#     'workforce,',
#     'Microsoft',
#     'announced',
#     'Intelligent',
#     'Cloud',
#     'Hub',
#     'which',
#     'has',
#     'been',
#     'launched',
#     'to',
#     'empower',
#     'the',
#     'next',
#     'generation',
#     'of',
#     'students',
#     'with',
#     'AI-ready',
#     'skills'])]]

# %%
# Finish off by printing summary.

for i in ranked_sentences:
    n = int(input("How many sentences do you want in the summary? "))
  
    for i in range(n):
        print("".join(ranked_sentence[i][1]))
# Out:
# How many sentences do you want in the summary? 5
# Thisprogramalsoincludeddeveloper-focusedAIschoolthatprovidedabunchofassetstohelpbuildAIskills.
# TheprogramwasdevelopedtoprovidejobreadyskillstoprogrammerswhowantedtohonetheirskillsinAIanddatasciencewithaseriesofonlinecourseswhichfeaturedhands-onlabsandexpertinstructorsaswell
# EarlierinAprilthisyear,thecompanyannouncedMicrosoftProfessionalProgramInAIasalearningtrackopentothepublic
# Theprogramisanattempttorampuptheinstitutionalset-upandbuildcapabilitiesamongtheeducatorstoeducatetheworkforceoftomorrow."Theprogramaimstobuildupthecognitiveskillsandin-depthunderstandingofdevelopingintelligentcloudconnectedsolutionsforapplicationsacrossindustry
# Thatâ€™swhyithasbecomemorecriticalthaneverforeducationalinstitutionstointegratenewcloudandAItechnologies
# How many sentences do you want in the summary? 6
# Thisprogramalsoincludeddeveloper-focusedAIschoolthatprovidedabunchofassetstohelpbuildAIskills.
# TheprogramwasdevelopedtoprovidejobreadyskillstoprogrammerswhowantedtohonetheirskillsinAIanddatasciencewithaseriesofonlinecourseswhichfeaturedhands-onlabsandexpertinstructorsaswell
# EarlierinAprilthisyear,thecompanyannouncedMicrosoftProfessionalProgramInAIasalearningtrackopentothepublic
# Theprogramisanattempttorampuptheinstitutionalset-upandbuildcapabilitiesamongtheeducatorstoeducatetheworkforceoftomorrow."Theprogramaimstobuildupthecognitiveskillsandin-depthunderstandingofdevelopingintelligentcloudconnectedsolutionsforapplicationsacrossindustry
# Thatâ€™swhyithasbecomemorecriticalthaneverforeducationalinstitutionstointegratenewcloudandAItechnologies
# ThiswillrequiremorecollaborationsandtrainingandworkingwithAI
# How many sentences do you want in the summary? 4
# Thisprogramalsoincludeddeveloper-focusedAIschoolthatprovidedabunchofassetstohelpbuildAIskills.
# TheprogramwasdevelopedtoprovidejobreadyskillstoprogrammerswhowantedtohonetheirskillsinAIanddatasciencewithaseriesofonlinecourseswhichfeaturedhands-onlabsandexpertinstructorsaswell
# EarlierinAprilthisyear,thecompanyannouncedMicrosoftProfessionalProgramInAIasalearningtrackopentothepublic
# Theprogramisanattempttorampuptheinstitutionalset-upandbuildcapabilitiesamongtheeducatorstoeducatetheworkforceoftomorrow."Theprogramaimstobuildupthecognitiveskillsandin-depthunderstandingofdevelopingintelligentcloudconnectedsolutionsforapplicationsacrossindustry
